# %%
from jikanpy import Jikan
jikan = Jikan()

# %%
mushishi = jikan.anime(553)

# %%
mushishi_with_eps = jikan.anime(457, extension='episodes')

# %%
mushishi_with_eps
# Out:
# {'request_hash': 'request:anime:0c0c8993424d2e48463d8cad2a48e76dd55b984f',
#  'request_cached': True,
#  'request_cache_expiry': 296016,
#  'episodes_last_page': 1,
#  'episodes': [{'episode_id': 1,
#    'title': 'The Green Seat',
#    'title_japanese': '緑の座',
#    'title_romanji': 'Midori no Za\xa0',
#    'aired': '2005-10-23T00:00:00+00:00',
#    'filler': False,
#    'recap': False,
#    'video_url': None,
#    'forum_url': 'https://myanimelist.net/forum/?topicid=12050'},
#   {'episode_id': 2,
#    'title': 'The Light of the Eyelid',
#    'title_japanese': '瞼の光',
#    'title_romanji': 'Mabuta no Hikari\xa0',
#    'aired': '2005-10-30T00:00:00+00:00',
#    'filler': False,
#    'recap': False,
#    'video_url': None,
#    'forum_url': 'https://myanimelist.net/forum/?topicid=12480'},
#   {'episode_id': 3,
#    'title': 'Tender Horns',
#    'title_japanese': '柔らかい角',
#    'title_romanji': 'Yawarakai Tsuno\xa0',
#    'aired': '2005-11-06T00:00:00+00:00',
#    'filler': False,
# ...

# %%
jikan.anime(61, extension='episodes')['episodes']
# Out:
# [{'episode_id': 1,
#   'title': 'Dark Revived',
#   'title_japanese': '復活のダーク',
#   'title_romanji': 'Fukkatsu no Dark\xa0',
#   'aired': '2003-04-03T00:00:00+00:00',
#   'filler': False,
#   'recap': False,
#   'video_url': None,
#   'forum_url': 'https://myanimelist.net/forum/?topicid=32253'},
#  {'episode_id': 2,
#   'title': 'Rekindled Feelings',
#   'title_japanese': 'よみがえる思い',
#   'title_romanji': 'Yomigaeru Omoi\xa0',
#   'aired': '2003-04-10T00:00:00+00:00',
#   'filler': False,
#   'recap': False,
#   'video_url': None,
#   'forum_url': 'https://myanimelist.net/forum/?topicid=72552'},
#  {'episode_id': 3,
#   'title': 'Whisper of the Unicorn',
#   'title_japanese': 'ユニコーンのささやき',
#   'title_romanji': 'Unicorn no Sasayaki\xa0',
#   'aired': '2003-04-17T00:00:00+00:00',
#   'filler': False,
#   'recap': False,
#   'video_url': None,
#   'forum_url': 'https://myanimelist.net/forum/?topicid=33399'},
#  {'episode_id': 4,
#   'title': 'Between Light and Darkness',
# ...
